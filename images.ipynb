# %%
import numpy as np
import pandas
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
import os
os.environ["LANG"] = "en_US.UTF-8"
import chromedriver_autoinstaller
import matplotlib.pyplot as plt
import bs4
import requests
from unidecode import unidecode
import re
import pandas as pd
from sklearn.metrics import r2_score

# %%
star_data = pd.read_csv('star_data.csv')
star_data
# Out:
#           Star Name  Distance (pc)  \
# 0         Absolutno     273.845058
# 1            Acamar      49.431537
# 2          Achernar      42.753313
# 3            Achird       5.923041
# 4           Acubens      54.554183
# ..              ...            ...
# 299        Zavijava      11.001766
# 300           Zhang      76.182930
# 301           Zibal      36.503011
# 302  Zubenelhakrabi      50.025013
# 303  Zubeneschamali      56.753689
#
#                                              Image URL       Spectral Class  \
# 0    https://alasky.u-strasbg.fr/hips-image-service...      ('G', '8', 'V')
# 1    https://alasky.u-strasbg.fr/hips-image-service...      ('A', '2', 'V')
# 2    https://alasky.u-strasbg.fr/hips-image-service...      ('B', '6', 'V')
# 3    https://alasky.u-strasbg.fr/hips-image-service...      ('F', '9', 'V')
# 4    https://alasky.u-strasbg.fr/hips-image-service...      ('A', '7', 'V')
# ..                                                 ...                  ...
# ...

# %%
# Display the images of the stars Cebalrai, Alrescha, Biham, Alrakis, and Athebyne
from IPython.display import Image
Image(filename='Star Images/Cebalrai.jpg')

# %%
Image(filename='Star Images/Alrescha.jpg')

# %%
Image(filename='Star Images/Biham.jpg')

# %%
Image(filename='Star Images/Alrakis.jpg')

# %%
Image(filename='Star Images/Athebyne.jpg')

# %%
# Find the things in common in the images of the stars Cebalrai, Alrescha, Biham, Alrakis, and Athebyne

# %%
# Display the images of the stars Azha, Azmidi, Beenim, Chalawan, and Dziban
Image(filename='Star Images/Azha.jpg')

# %%
Image(filename='Star Images/Azmidi.jpg')

# %%
Image(filename='Star Images/Beemim.jpg')

# %%
Image(filename='Star Images/Chalawan.jpg')

# %%
Image(filename='Star Images/Dziban.jpg')

# %%
# Identify what the images of Cebalrai, Alrescha, Biham, Alrakis, and Athebyne have in common
